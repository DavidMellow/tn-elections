# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
tn_2016=pd.read_excel('../data/2016_election/StateGeneralbyPrecinctNov2016.xlsx',
                      usecols=['COUNTY','PRECINCT','OFFICENAME','ELECTDATE','RNAME1','PARTY1','PVTALLY1',
                             'RNAME2','PARTY2','PVTALLY2','RNAME3','PARTY3','PVTALLY3','RNAME4','PARTY4','PVTALLY4',
                             'RNAME5','PARTY5','PVTALLY5','RNAME6','PARTY6','PVTALLY6','RNAME7','PARTY7','PVTALLY7',
                             'RNAME8','PARTY8','PVTALLY8','RNAME9','PARTY9','PVTALLY9','RNAME10','PARTY10','PVTALLY10'])
tn_2016
# Out:
#         COUNTY       PRECINCT  \
# 0     Anderson  Andersonville
# 1     Anderson  Andersonville
# 2     Anderson  Andersonville
# 3     Anderson  Andersonville
# 4     Anderson     Briceville
# ...        ...            ...
# 9397    Wilson       Absentee
# 9398    Wilson       Absentee
# 9399    Wilson       Absentee
# 9400    Wilson       Absentee
# 9401    Wilson       Absentee
#
#                                              OFFICENAME   ELECTDATE  \
# 0                               United States President  2016-11-08
# 1                               United States President  2016-11-08
# 2     United States House of Representatives District 3  2016-11-08
# 3        Tennessee House of Representatives District 36  2016-11-08
# 4                               United States President  2016-11-08
# ...                                                 ...         ...
# 9397                            United States President  2016-11-08
# ...

# %%
#lower case column names
tn_2016.columns=tn_2016.columns.str.lower()
tn_2016.head(2)
# Out:
#      county       precinct               officename   electdate  \
# 0  Anderson  Andersonville  United States President  2016-11-08
# 1  Anderson  Andersonville  United States President  2016-11-08
#
#                            rname1      party1  pvtally1  \
# 0                 Donald J. Trump  Republican      1222
# 1  Write-In - Kyle Kenley Kopitke         NaN         0
#
#                           rname2      party2  pvtally2  \
# 0                Hillary Clinton  Democratic     227.0
# 1  Write-In - Laurence Kotlikoff         NaN       0.0
#
#                        rname3       party3  pvtally3  \
# 0  "Rocky" Roque De La Fuente  Independent       2.0
# 1   Write-In - David Limbaugh          NaN       0.0
#
#                      rname4       party4  pvtally4  \
# 0              Gary Johnson  Independent      32.0
# 1  Write-In - Evan McMullin          NaN       3.0
#
#                          rname5       party5  pvtally5      rname6  \
# ...

# %%
tn_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9402 entries, 0 to 9401
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   county      9402 non-null   object
#  1   precinct    9402 non-null   object
#  2   officename  9402 non-null   object
#  3   electdate   9402 non-null   object
#  4   rname1      9402 non-null   object
#  5   party1      7561 non-null   object
#  6   pvtally1    9402 non-null   int64
#  7   rname2      7984 non-null   object
#  8   party2      6088 non-null   object
#  9   pvtally2    7984 non-null   float64
#  10  rname3      5738 non-null   object
#  11  party3      3787 non-null   object
#  12  pvtally3    5738 non-null   float64
#  13  rname4      4913 non-null   object
#  14  party4      2726 non-null   object
#  15  pvtally4    4913 non-null   float64
#  16  rname5      4567 non-null   object
#  17  party5      2726 non-null   object
#  18  pvtally5    4567 non-null   float64
# ...

# %%
#fill NaN in party column with "No party declared"
tn_2016['party1'].fillna("No party declared", inplace = True)
tn_2016['party2'].fillna("No party declared", inplace = True)
tn_2016['party3'].fillna("No party declared", inplace = True)
tn_2016['party4'].fillna("No party declared", inplace = True)
tn_2016['party5'].fillna("No party declared", inplace = True)
tn_2016['party6'].fillna("No party declared", inplace = True)
tn_2016['party7'].fillna("No party declared", inplace = True)
tn_2016['party8'].fillna("No party declared", inplace = True)
tn_2016['party9'].fillna("No party declared", inplace = True)
tn_2016['party10'].fillna("No party declared", inplace = True)
tn_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9402 entries, 0 to 9401
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   county      9402 non-null   object
#  1   precinct    9402 non-null   object
#  2   officename  9402 non-null   object
#  3   electdate   9402 non-null   object
#  4   rname1      9402 non-null   object
#  5   party1      9402 non-null   object
#  6   pvtally1    9402 non-null   int64
#  7   rname2      7984 non-null   object
#  8   party2      9402 non-null   object
#  9   pvtally2    7984 non-null   float64
#  10  rname3      5738 non-null   object
#  11  party3      9402 non-null   object
#  12  pvtally3    5738 non-null   float64
#  13  rname4      4913 non-null   object
#  14  party4      9402 non-null   object
#  15  pvtally4    4913 non-null   float64
#  16  rname5      4567 non-null   object
#  17  party5      9402 non-null   object
#  18  pvtally5    4567 non-null   float64
# ...

# %%
pvtally=tn_2016.columns[tn_2016.columns.str.contains('pvtally')]#.fillna(0,inplace=True)
pvtally
# Out:
# Index(['pvtally1', 'pvtally2', 'pvtally3', 'pvtally4', 'pvtally5', 'pvtally6',
#        'pvtally7', 'pvtally8', 'pvtally9', 'pvtally10'],
#       dtype='object')

# %%
#df.loc[df['set_of_numbers'].isnull(), 'set_of_numbers'] = 0
tn_2016.loc[tn_2016['pvtally'].isna(),'pvtally'] = 0 
tn_2016.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pvtally'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-282-9ef0164b9d2e> in <module>
# ...

# %%
#tn_2016.loc[pvtally] = tn_2016.loc[pvtally].fillna(0,inplace=True)
tn_2016.loc[pvtally]=tn_2016.loc[pvtally].fillna(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-279-32db528f746d> in <module>
#       1 #tn_2016.loc[pvtally] = tn_2016.loc[pvtally].fillna(0,inplace=True)
# ----> 2 tn_2016.loc[pvtally]=tn_2016.loc[pvtally].fillna(0,inplace=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1951                     raise ValueError("Cannot index with multidimensional key")
#    1952
# -> 1953                 return self._getitem_iterable(key, axis=axis)
#    1954
# ...

# %%
#convert float64's to int64's
#party=tn_2016.columns[tn_2016.columns.str.contains('pvtally')]
#tn_2016=tn_2016.astype({'pvtally2':'int64','pvtally3':'int64','pvtally4':'int64','pvtally5':'int64','pvtally6':'int64','pvtally7':'int64','pvtally8':'int64','pvtally9':'int64','pvtally10':'int64'},errors='ignore')
tn_2016=tn_2016.astype({'pvtally2':'int64'},errors='ignore')

# %% [markdown]
# def pvtally():
#     return tn_2016.columns.str.contains('pvtally')
# pvtally.fillna(0,inplace=True)
# tn_2016.info

# %% [markdown]
#  tn_2016.apply(lambda row: row(tn_2016.columns.str.contains('pvtally').fillna(0,inplace=True)))

# %%
tn_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9402 entries, 0 to 9401
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   county      9402 non-null   object
#  1   precinct    9402 non-null   object
#  2   officename  9402 non-null   object
#  3   electdate   9402 non-null   object
#  4   rname1      9402 non-null   object
#  5   party1      9402 non-null   object
#  6   pvtally1    9402 non-null   int64
#  7   rname2      7984 non-null   object
#  8   party2      9402 non-null   object
#  9   pvtally2    7984 non-null   float64
#  10  rname3      5738 non-null   object
#  11  party3      9402 non-null   object
#  12  pvtally3    5738 non-null   float64
#  13  rname4      4913 non-null   object
#  14  party4      9402 non-null   object
#  15  pvtally4    4913 non-null   float64
#  16  rname5      4567 non-null   object
#  17  party5      9402 non-null   object
#  18  pvtally5    4567 non-null   float64
# ...
