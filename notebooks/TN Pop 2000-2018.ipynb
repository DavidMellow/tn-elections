# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %%
# import excel file TN_co-est2000-09-int-01-47.xls
tn_pop_2000=pd.read_excel('../data/US Census/TN_co-est2000-09-int-01-47.xls',
                         header=3)
tn_pop_2000
# Out:
#                                             Unnamed: 0  Unnamed: 1       2000  \
# 0                                            Tennessee   5689427.0  5703719.0
# 1                                     .Anderson County     71470.0    71357.0
# 2                                      .Bedford County     37608.0    37806.0
# 3                                       .Benton County     16534.0    16537.0
# 4                                      .Bledsoe County     12349.0    12390.0
# ..                                                 ...         ...        ...
# 99   Note: All geographic boundaries for the 2000-2...         NaN        NaN
# 100                                Suggested Citation:         NaN        NaN
# 101  Table 1. Intercensal Estimates of the Resident...         NaN        NaN
# 102    Source: U.S. Census Bureau, Population Division         NaN        NaN
# 103                       Release Date: September 2011         NaN        NaN
#
# ...

# %%
tn_pop_2000.tail(10)
# Out:
#                                             Unnamed: 0  Unnamed: 1      2000  \
# 94                                  .Williamson County    126649.0  128134.0
# 95                                      .Wilson County     88794.0   89220.0
# 96   1 The April 1, 2000 Population Estimates base ...         NaN       NaN
# 97   2 The data source for April 1, 2010 is the 201...         NaN       NaN
# 98   3 The values for July 1, 2010 were produced by...         NaN       NaN
# 99   Note: All geographic boundaries for the 2000-2...         NaN       NaN
# 100                                Suggested Citation:         NaN       NaN
# 101  Table 1. Intercensal Estimates of the Resident...         NaN       NaN
# 102    Source: U.S. Census Bureau, Population Division         NaN       NaN
# 103                       Release Date: September 2011         NaN       NaN
#
#          2001      2002      2003      2004      2005      2006      2007  \
# ...

# %%
tn_pop_2000.rename(columns={'Unnamed: 0':'geographic_area','Unnamed: 1':'april_1_2000','Unnamed: 12':'april_1_2010',
                   'Unnamed: 13':'july_1_2010'},inplace=True)
tn_pop_2000.head(2)
# Out:
#     geographic_area  april_1_2000       2000       2001       2002       2003  \
# 0         Tennessee     5689427.0  5703719.0  5750789.0  5795918.0  5847812.0
# 1  .Anderson County       71470.0    71357.0    71461.0    71515.0    71608.0
#
#         2004       2005       2006       2007       2008       2009  \
# 0  5910809.0  5991057.0  6088766.0  6175727.0  6247411.0  6306019.0
# 1    71587.0    72040.0    73117.0    73580.0    74397.0    75031.0
#
#    april_1_2010  july_1_2010
# 0     6346105.0    6356897.0
# 1       75129.0      75160.0

# %%
# drop rows 96-103  
tn_pop_2000=tn_pop_2000[0:96]
tn_pop_2000.tail(10)
# Out:
#        geographic_area  april_1_2000      2000      2001      2002      2003  \
# 86      .Unicoi County       17666.0   17686.0   17642.0   17765.0   17918.0
# 87       .Union County       17843.0   17891.0   18322.0   18453.0   18652.0
# 88   .Van Buren County        5505.0    5507.0    5475.0    5505.0    5415.0
# 89      .Warren County       38275.0   38371.0   38566.0   38500.0   38828.0
# 90  .Washington County      107188.0  107469.0  107775.0  109526.0  110592.0
# 91       .Wayne County       16817.0   16819.0   17075.0   17078.0   17036.0
# 92     .Weakley County       34917.0   34927.0   34491.0   34443.0   34300.0
# 93       .White County       23139.0   23160.0   23468.0   23650.0   23754.0
# 94  .Williamson County      126649.0  128134.0  132536.0  136953.0  141876.0
# 95      .Wilson County       88794.0   89220.0   91020.0   93033.0   94924.0
#
#         2004      2005      2006      2007      2008      2009  april_1_2010  \
# ...

# %%
tn_pop_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   geographic_area  96 non-null     object
#  1   april_1_2000     96 non-null     float64
#  2   2000             96 non-null     float64
#  3   2001             96 non-null     float64
#  4   2002             96 non-null     float64
#  5   2003             96 non-null     float64
#  6   2004             96 non-null     float64
#  7   2005             96 non-null     float64
#  8   2006             96 non-null     float64
#  9   2007             96 non-null     float64
#  10  2008             96 non-null     float64
#  11  2009             96 non-null     float64
#  12  april_1_2010     96 non-null     float64
#  13  july_1_2010      96 non-null     float64
# dtypes: float64(13), object(1)
# memory usage: 10.6+ KB

# %%
# clean up county names
tn_pop_2000.loc[:,'geographic_area']=tn_pop_2000['geographic_area'].str.replace('.','').str.replace(' ','').str.replace('County','')
tn_pop_2000.head(5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#   geographic_area  april_1_2000       2000       2001       2002       2003  \
# 0       Tennessee     5689427.0  5703719.0  5750789.0  5795918.0  5847812.0
# 1        Anderson       71470.0    71357.0    71461.0    71515.0    71608.0
# 2         Bedford       37608.0    37806.0    38414.0    38960.0    39697.0
# 3          Benton       16534.0    16537.0    16673.0    16572.0    16531.0
# 4         Bledsoe       12349.0    12390.0    12468.0    12446.0    12502.0
#
#         2004       2005       2006       2007       2008       2009  \
# ...

# %%
# only need election year columns (even years)
tn_pop_2000=tn_pop_2000.drop(['april_1_2000',2001,2003,2005,2007,2009,'april_1_2010','july_1_2010'],axis=1)
tn_pop_2000.head(5)
# Out:
#   geographic_area       2000       2002       2004       2006       2008
# 0       Tennessee  5703719.0  5795918.0  5910809.0  6088766.0  6247411.0
# 1        Anderson    71357.0    71515.0    71587.0    73117.0    74397.0
# 2         Bedford    37806.0    38960.0    40558.0    42780.0    44395.0
# 3          Benton    16537.0    16572.0    16517.0    16435.0    16431.0
# 4         Bledsoe    12390.0    12446.0    12610.0    12847.0    13070.0

# %%
# import excel file TN_co-est2010-19-annres-47.xlsx
tn_pop_2010=pd.read_excel('../data/US Census/TN_co-est2010-19-annres-47.xlsx',
                         header=3)
tn_pop_2010
# Out:
#                                             Unnamed: 0     Census  \
# 0                                            Tennessee  6346105.0
# 1                          .Anderson County, Tennessee    75129.0
# 2                           .Bedford County, Tennessee    45058.0
# 3                            .Benton County, Tennessee    16489.0
# 4                           .Bledsoe County, Tennessee    12876.0
# ..                                                 ...        ...
# 96   Note: The estimates are based on the 2010 Cens...        NaN
# 97                                 Suggested Citation:        NaN
# 98   Annual Estimates of the Resident Population fo...        NaN
# 99     Source: U.S. Census Bureau, Population Division        NaN
# 100                           Release Date: March 2020        NaN
#
#      Estimates Base       2010       2011       2012       2013       2014  \
# 0         6346276.0  6355311.0  6399291.0  6453898.0  6494340.0  6541223.0
# ...

# %%
tn_pop_2010.tail(10)
# Out:
#                                             Unnamed: 0    Census  \
# 91                            .Wayne County, Tennessee   17021.0
# 92                          .Weakley County, Tennessee   35021.0
# 93                            .White County, Tennessee   25841.0
# 94                       .Williamson County, Tennessee  183182.0
# 95                           .Wilson County, Tennessee  113993.0
# 96   Note: The estimates are based on the 2010 Cens...       NaN
# 97                                 Suggested Citation:       NaN
# 98   Annual Estimates of the Resident Population fo...       NaN
# 99     Source: U.S. Census Bureau, Population Division       NaN
# 100                           Release Date: March 2020       NaN
#
#      Estimates Base      2010      2011      2012      2013      2014  \
# 91          17025.0   16985.0   17000.0   16973.0   16920.0   16860.0
# 92          35015.0   35044.0   34857.0   34554.0   34155.0   34001.0
# ...

# %%
tn_pop_2010.rename(columns={'Unnamed: 0':'geographic_area'},inplace=True)
tn_pop_2010.head(2)
# Out:
#                geographic_area     Census  Estimates Base       2010  \
# 0                    Tennessee  6346105.0       6346276.0  6355311.0
# 1  .Anderson County, Tennessee    75129.0         75082.0    75098.0
#
#         2011       2012       2013       2014       2015       2016  \
# 0  6399291.0  6453898.0  6494340.0  6541223.0  6591170.0  6646010.0
# 1    75209.0    75225.0    75299.0    75157.0    75456.0    75528.0
#
#         2017       2018       2019
# 0  6708799.0  6771631.0  6829174.0
# 1    76056.0    76287.0    76978.0

# %%
# drop rows 96-103  df[:3] #keep top 3
tn_pop_2010=tn_pop_2010[0:96]
tn_pop_2010.tail(10)
# Out:
#                   geographic_area    Census  Estimates Base      2010  \
# 86      .Unicoi County, Tennessee   18313.0         18311.0   18284.0
# 87       .Union County, Tennessee   19109.0         19107.0   19116.0
# 88   .Van Buren County, Tennessee    5548.0          5558.0    5569.0
# 89      .Warren County, Tennessee   39839.0         39824.0   39858.0
# 90  .Washington County, Tennessee  122979.0        123063.0  123384.0
# 91       .Wayne County, Tennessee   17021.0         17025.0   16985.0
# 92     .Weakley County, Tennessee   35021.0         35015.0   35044.0
# 93       .White County, Tennessee   25841.0         25844.0   25828.0
# 94  .Williamson County, Tennessee  183182.0        183277.0  184143.0
# 95      .Wilson County, Tennessee  113993.0        114062.0  114677.0
#
#         2011      2012      2013      2014      2015      2016      2017  \
# 86   18302.0   18253.0   18095.0   17951.0   17819.0   17737.0   17796.0
# ...

# %%
tn_pop_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   geographic_area  96 non-null     object
#  1   Census           96 non-null     float64
#  2   Estimates Base   96 non-null     float64
#  3   2010             96 non-null     float64
#  4   2011             96 non-null     float64
#  5   2012             96 non-null     float64
#  6   2013             96 non-null     float64
#  7   2014             96 non-null     float64
#  8   2015             96 non-null     float64
#  9   2016             96 non-null     float64
#  10  2017             96 non-null     float64
#  11  2018             96 non-null     float64
#  12  2019             96 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 9.9+ KB

# %%
# split "geographic_area" column to put "Tennesee" in new column   df[['First','Last']] = df.Name.str.split(expand=True) 
tn_pop_2010[['geographic_area','state']]=tn_pop_2010['geographic_area'].str.split(',',expand=True)
tn_pop_2010
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        geographic_area     Census  Estimates Base       2010       2011  \
# 0            Tennessee  6346105.0       6346276.0  6355311.0  6399291.0
# 1     .Anderson County    75129.0         75082.0    75098.0    75209.0
# 2      .Bedford County    45058.0         45057.0    45078.0    45247.0
# 3       .Benton County    16489.0         16491.0    16511.0    16529.0
# 4      .Bledsoe County    12876.0         12874.0    12884.0    12992.0
# ..                 ...        ...             ...        ...        ...
# 91       .Wayne County    17021.0         17025.0    16985.0    17000.0
# ...

# %%
# clean up county names
tn_pop_2010.loc[:,'geographic_area']=tn_pop_2010['geographic_area'].str.replace('.','').str.replace(' ','').str.replace('County','')
tn_pop_2010.head(5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#   geographic_area     Census  Estimates Base       2010       2011       2012  \
# 0       Tennessee  6346105.0       6346276.0  6355311.0  6399291.0  6453898.0
# 1        Anderson    75129.0         75082.0    75098.0    75209.0    75225.0
# 2         Bedford    45058.0         45057.0    45078.0    45247.0    45254.0
# 3          Benton    16489.0         16491.0    16511.0    16529.0    16445.0
# 4         Bledsoe    12876.0         12874.0    12884.0    12992.0    12926.0
#
#         2013       2014       2015       2016       2017       2018  \
# ...

# %%
# only need election year columns (even years)
tn_pop_2010=tn_pop_2010.drop(['Census','Estimates Base',2011,2013,2015,2017,2019,'state'],axis=1)
tn_pop_2010.head(5)
# Out:
#   geographic_area       2010       2012       2014       2016       2018
# 0       Tennessee  6355311.0  6453898.0  6541223.0  6646010.0  6771631.0
# 1        Anderson    75098.0    75225.0    75157.0    75528.0    76287.0
# 2         Bedford    45078.0    45254.0    46251.0    47442.0    49146.0
# 3          Benton    16511.0    16445.0    16197.0    16082.0    16246.0
# 4         Bledsoe    12884.0    12926.0    14501.0    14738.0    14883.0

# %%
# merge dataframes into "tn_pop_2000_2018"
tn_pop_2000_2018=pd.merge(tn_pop_2000,tn_pop_2010, on='geographic_area')
tn_pop_2000_2018
# Out:
#    geographic_area       2000       2002       2004       2006       2008  \
# 0        Tennessee  5703719.0  5795918.0  5910809.0  6088766.0  6247411.0
# 1         Anderson    71357.0    71515.0    71587.0    73117.0    74397.0
# 2          Bedford    37806.0    38960.0    40558.0    42780.0    44395.0
# 3           Benton    16537.0    16572.0    16517.0    16435.0    16431.0
# 4          Bledsoe    12390.0    12446.0    12610.0    12847.0    13070.0
# ..             ...        ...        ...        ...        ...        ...
# 91           Wayne    16819.0    17078.0    17010.0    17033.0    17004.0
# 92         Weakley    34927.0    34443.0    34307.0    34289.0    34484.0
# 93           White    23160.0    23650.0    24069.0    24866.0    25548.0
# 94      Williamson   128134.0   136953.0   147439.0   161902.0   175498.0
# 95          Wilson    89220.0    93033.0    97139.0   103697.0   110474.0
#
#          2010       2012       2014       2016       2018
# ...

# %%
tn_pop_2000_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   geographic_area  96 non-null     object
#  1   2000             96 non-null     float64
#  2   2002             96 non-null     float64
#  3   2004             96 non-null     float64
#  4   2006             96 non-null     float64
#  5   2008             96 non-null     float64
#  6   2010             96 non-null     float64
#  7   2012             96 non-null     float64
#  8   2014             96 non-null     float64
#  9   2016             96 non-null     float64
#  10  2018             96 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 9.0+ KB

# %%
# change float64's to int32's to drop decimal
tn_pop_2000_2018=tn_pop_2000_2018.astype({2000:'int32',2002:'int32',2004:'int32',2006:'int32',2008:'int32',
                         2010:'int32',2012:'int32',2014:'int32',2016:'int32',2018:'int32',})
tn_pop_2000_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   geographic_area  96 non-null     object
#  1   2000             96 non-null     int32
#  2   2002             96 non-null     int32
#  3   2004             96 non-null     int32
#  4   2006             96 non-null     int32
#  5   2008             96 non-null     int32
#  6   2010             96 non-null     int32
#  7   2012             96 non-null     int32
#  8   2014             96 non-null     int32
#  9   2016             96 non-null     int32
#  10  2018             96 non-null     int32
# dtypes: int32(10), object(1)
# memory usage: 5.2+ KB

# %%
# add county index number for possible mapping
county_index=pd.read_csv('../data/TN_county_index_shape.csv')
county_index
# Out:
#         county  INDEX_NO
# 0     Anderson        79
# 1      Bedford        26
# 2       Benton        41
# 3      Bledsoe        31
# 4       Blount        52
# ..         ...       ...
# 90       Wayne         6
# 91     Weakley        56
# 92       White        67
# 93  Williamson        44
# 94      Wilson        65
#
# [95 rows x 2 columns]

# %%
# add "Tennessee" and "0" to first row to allow join
county_index.loc[-1]=['Tennessee',0]
county_index.index=county_index.index+1
county_index=county_index.sort_index()
county_index
# Out:
#         county  INDEX_NO
# 0    Tennessee         0
# 1     Anderson        79
# 2      Bedford        26
# 3       Benton        41
# 4      Bledsoe        31
# ..         ...       ...
# 91       Wayne         6
# 92     Weakley        56
# 93       White        67
# 94  Williamson        44
# 95      Wilson        65
#
# [96 rows x 2 columns]

# %%
# join to df "tn_pop_2000_2018"
county_num=county_index['INDEX_NO']
tn_pop_2000_2018=tn_pop_2000_2018.join(county_num)
tn_pop_2000_2018
# Out:
#    geographic_area     2000     2002     2004     2006     2008     2010  \
# 0        Tennessee  5703719  5795918  5910809  6088766  6247411  6355311
# 1         Anderson    71357    71515    71587    73117    74397    75098
# 2          Bedford    37806    38960    40558    42780    44395    45078
# 3           Benton    16537    16572    16517    16435    16431    16511
# 4          Bledsoe    12390    12446    12610    12847    13070    12884
# ..             ...      ...      ...      ...      ...      ...      ...
# 91           Wayne    16819    17078    17010    17033    17004    16985
# 92         Weakley    34927    34443    34307    34289    34484    35044
# 93           White    23160    23650    24069    24866    25548    25828
# 94      Williamson   128134   136953   147439   161902   175498   184143
# 95          Wilson    89220    93033    97139   103697   110474   114677
#
#        2012     2014     2016     2018  INDEX_NO
# ...

# %%
tn_pop_2000_2018.to_excel(r'../data/US Census/tn_pop_2000_2018.xlsx',index=False)
